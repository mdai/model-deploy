# %% [markdown]
# ## Classification of chest vs. adominal X-rays

# %%
# %%script bash
#
# pip install -q -U mdai

# %%
import mdai
mdai.__version__
# Out:
# '0.4.0'

# %%
mdai_client = mdai.Client(domain='public.md.ai', access_token="")
# Out:
# Successfully authenticated to public.md.ai.

# %%
p = mdai_client.project('PVq9raBJ', path='./data')
# Out:
# Using path './data' for data.
# Preparing annotations export for project PVq9raBJ...
# Using cached annotations data for project PVq9raBJ.
# Preparing images export for project PVq9raBJ...
# Using cached images data for project PVq9raBJ.

# %% [markdown]
# ### Set label ids
#
# Selected label ids must be explicitly set by `Project#set_label_ids` method in order to prepare datasets.

# %%
p.show_label_groups()
# Out:
# Label Group, Id: G_BdW4M5, Name: Default group
# 	Labels:
# 	Id: L_38Y7Jl, Name: Abdomen
# 	Id: L_z8xEkB, Name: Chest

# %%
# this maps label ids to class ids as a dict obj
labels_dict = {
    'L_38Y7Jl': 0, # Abdomen 
    'L_z8xEkB': 1, # Chest  
}

print(labels_dict)
p.set_labels_dict(labels_dict)
# Out:
# {'L_38Y7Jl': 0, 'L_z8xEkB': 1}

# %% [markdown]
# ### Create the *Training* and *Validation* datasets

# %%
p.show_datasets()
# Out:
# Datasets:
# Id: D_8ogmzN, Name: TRAIN
# Id: D_OoJ98E, Name: VAL
# Id: D_8oAvmQ, Name: TEST

# %%
# create training dataset 
train_dataset = p.get_dataset_by_name('TRAIN')
train_dataset.prepare() 
train_image_ids = train_dataset.get_image_ids()
print(len(train_image_ids))

# create the validation dataset 
val_dataset = p.get_dataset_by_name('VAL')
val_dataset.prepare()
val_image_ids = val_dataset.get_image_ids()
print(len(val_image_ids))
# Out:
# 65
# 10

# %% [markdown]
# ### Display a few images

# %%
# visualize a few train images 
mdai.visualize.display_images(train_image_ids[:2], cols=2)
mdai.visualize.display_images(val_image_ids[:2], cols=2)

# %% [markdown]
# ### Use keras for training and validation

# %%
import tensorflow as tf

tf.keras.backend.clear_session()

# %%
# Define model parameters 
img_width = 224
img_height = 224
epochs = 100

params = {
    'dim': (img_width, img_height),
    'batch_size': 5,
    'n_classes': 2,
    'n_channels': 3,
    'shuffle': True,
}

# %%
base_model = tf.keras.applications.MobileNet(weights='imagenet', include_top=False, input_shape=(img_width, img_height, 3))

output = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
output = tf.keras.layers.Dense(2, activation='softmax')(output)

model = tf.keras.Model(inputs=base_model.input, outputs=output)

model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.0001), 
              loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 225, 225, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 113, 113, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 57, 57, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 29, 29, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 2050
# =================================================================
# Total params: 3,230,914
# Trainable params: 3,209,026
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
from mdai.visualize import load_dicom_image
import numpy as np
from PIL import Image


class DataGenerator(tf.keras.utils.Sequence):
    def __init__(
        self,
        dataset,
        batch_size=32,
        dim=(32, 32),
        n_channels=1,
        n_classes=10,
        shuffle=True,
        to_RGB=True,
        rescale=False,
    ):
        """Generates data for Keras fit_generator() function.
        """

        # Initialization
        self.dim = dim
        self.batch_size = batch_size

        self.img_ids = dataset.image_ids
        self.imgs_anns_dict = dataset.imgs_anns_dict
        self.dataset = dataset

        self.n_channels = n_channels
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.to_RGB = to_RGB
        self.rescale = rescale
        self.on_epoch_end()

    def __len__(self):
        "Denotes the number of batches per epoch"
        return int(np.floor(len(self.img_ids) / self.batch_size))

    def __getitem__(self, index):
        "Generate one batch of data"

        # Generate indexes of the batch
        indexes = self.indexes[index * self.batch_size : (index + 1) * self.batch_size]

        # Find list of IDs
        img_ids_temp = [self.img_ids[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(img_ids_temp)

        return X, y

    def on_epoch_end(self):
        "Updates indexes after each epoch"
        self.indexes = np.arange(len(self.img_ids))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __data_generation(self, img_ids_temp):
        "Generates data containing batch_size samples"

        # Initialization
        X = np.empty((self.batch_size, *self.dim, self.n_channels))
        y = np.empty((self.batch_size), dtype=int)

        # Generate data
        for i, ID in enumerate(img_ids_temp):
            image = load_dicom_image(ID, to_RGB=self.to_RGB, rescale=self.rescale)
            try:
                image = Image.fromarray(image)
            except Exception:
                print(
                    "Pil.Image can't read image. Possible 12 or 16 bit image. Try rescale=True to "
                    + "scale to 8 bit."
                )

            image = image.resize((self.dim[0], self.dim[1]))

            X[i,] = image

            ann = self.imgs_anns_dict[ID][0]
            y[i] = self.dataset.classes_dict[ann["labelId"]]["class_id"]
        return X, tf.keras.utils.to_categorical(y, num_classes=self.n_classes)

# %%
train_generator = DataGenerator(train_dataset, **params)
val_generator = DataGenerator(val_dataset, **params)

# %%
# Set callback functions to early stop training and save the best model so far
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=2),
    tf.keras.callbacks.ModelCheckpoint(filepath='./model.h5', monitor='val_loss', 
                                       save_best_only=True, verbose=2)
]

history = model.fit_generator(
    generator=train_generator,
    epochs=epochs,
    callbacks=callbacks,
    verbose=1,
    validation_data=val_generator,
    use_multiprocessing=True, 
    workers=6
)
# Out:
# Epoch 1/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.2714 - accuracy: 0.9000
# Epoch 00001: val_loss improved from inf to 2.10491, saving model to ./model.h5
# 13/13 [==============================] - 3s 229ms/step - loss: 0.2513 - accuracy: 0.9077 - val_loss: 2.1049 - val_accuracy: 0.5000
# Epoch 2/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0489 - accuracy: 0.9833
# Epoch 00002: val_loss improved from 2.10491 to 1.26221, saving model to ./model.h5
# 13/13 [==============================] - 2s 138ms/step - loss: 0.0452 - accuracy: 0.9846 - val_loss: 1.2622 - val_accuracy: 0.5000
# Epoch 3/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.2639 - accuracy: 0.8500
# Epoch 00003: val_loss improved from 1.26221 to 0.70779, saving model to ./model.h5
# 13/13 [==============================] - 2s 155ms/step - loss: 0.2436 - accuracy: 0.8615 - val_loss: 0.7078 - val_accuracy: 0.7000
# Epoch 4/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1813 - accuracy: 0.9333
# Epoch 00004: val_loss improved from 0.70779 to 0.45067, saving model to ./model.h5
# 13/13 [==============================] - 2s 134ms/step - loss: 0.1676 - accuracy: 0.9385 - val_loss: 0.4507 - val_accuracy: 0.9000
# Epoch 5/100
# 12/13 [==========================>...] - ETA: 0s - loss: 4.9940e-04 - accuracy: 1.0000
# Epoch 00005: val_loss improved from 0.45067 to 0.37908, saving model to ./model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 4.8296e-04 - accuracy: 1.0000 - val_loss: 0.3791 - val_accuracy: 0.9000
# Epoch 6/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1904 - accuracy: 0.9333
# Epoch 00006: val_loss improved from 0.37908 to 0.09217, saving model to ./model.h5
# 13/13 [==============================] - 2s 155ms/step - loss: 0.1759 - accuracy: 0.9385 - val_loss: 0.0922 - val_accuracy: 1.0000
# Epoch 7/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1311 - accuracy: 0.9833
# Epoch 00007: val_loss improved from 0.09217 to 0.04411, saving model to ./model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.1858 - accuracy: 0.9538 - val_loss: 0.0441 - val_accuracy: 1.0000
# Epoch 8/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0518 - accuracy: 0.9833
# Epoch 00008: val_loss improved from 0.04411 to 0.01974, saving model to ./model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0479 - accuracy: 0.9846 - val_loss: 0.0197 - val_accuracy: 1.0000
# Epoch 9/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 00009: val_loss improved from 0.01974 to 0.00690, saving model to ./model.h5
# 13/13 [==============================] - 2s 134ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 10/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1382 - accuracy: 0.9167
# Epoch 00010: val_loss improved from 0.00690 to 0.00366, saving model to ./model.h5
# 13/13 [==============================] - 2s 138ms/step - loss: 0.2133 - accuracy: 0.9077 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 11/100
# 12/13 [==========================>...] - ETA: 0s - loss: 8.0509e-04 - accuracy: 1.0000
# Epoch 00011: val_loss did not improve from 0.00366
# 13/13 [==============================] - 2s 117ms/step - loss: 7.7207e-04 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 12/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 00012: val_loss did not improve from 0.00366
# 13/13 [==============================] - 2s 131ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 13/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0125 - accuracy: 1.0000
# Epoch 00013: val_loss improved from 0.00366 to 0.00314, saving model to ./model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 14/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0333 - accuracy: 0.9833
# Epoch 00014: val_loss improved from 0.00314 to 0.00274, saving model to ./model.h5
# 13/13 [==============================] - 2s 156ms/step - loss: 0.0318 - accuracy: 0.9846 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 15/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 00015: val_loss improved from 0.00274 to 0.00217, saving model to ./model.h5
# 13/13 [==============================] - 2s 148ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 16/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 00016: val_loss improved from 0.00217 to 0.00122, saving model to ./model.h5
# 13/13 [==============================] - 2s 147ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 17/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0779 - accuracy: 0.9500
# Epoch 00017: val_loss improved from 0.00122 to 0.00120, saving model to ./model.h5
# 13/13 [==============================] - 2s 152ms/step - loss: 0.0719 - accuracy: 0.9538 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 18/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0463 - accuracy: 0.9833
# Epoch 00018: val_loss improved from 0.00120 to 0.00042, saving model to ./model.h5
# 13/13 [==============================] - 2s 150ms/step - loss: 0.0427 - accuracy: 0.9846 - val_loss: 4.2104e-04 - val_accuracy: 1.0000
# Epoch 19/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 00019: val_loss improved from 0.00042 to 0.00025, saving model to ./model.h5
# 13/13 [==============================] - 2s 151ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 2.5266e-04 - val_accuracy: 1.0000
# Epoch 20/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 00020: val_loss improved from 0.00025 to 0.00022, saving model to ./model.h5
# 13/13 [==============================] - 2s 150ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 2.1668e-04 - val_accuracy: 1.0000
# Epoch 21/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 00021: val_loss improved from 0.00022 to 0.00019, saving model to ./model.h5
# 13/13 [==============================] - 2s 150ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.8544e-04 - val_accuracy: 1.0000
# Epoch 22/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00022: val_loss did not improve from 0.00019
# 13/13 [==============================] - 2s 133ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.0898e-04 - val_accuracy: 1.0000
# Epoch 23/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0417 - accuracy: 0.9833
# Epoch 00023: val_loss did not improve from 0.00019
# 13/13 [==============================] - 2s 125ms/step - loss: 0.1121 - accuracy: 0.9385 - val_loss: 2.3593e-04 - val_accuracy: 1.0000
# Epoch 24/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0426 - accuracy: 0.9833
# Epoch 00024: val_loss did not improve from 0.00019
# 13/13 [==============================] - 2s 134ms/step - loss: 0.0394 - accuracy: 0.9846 - val_loss: 2.1984e-04 - val_accuracy: 1.0000
# Epoch 25/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 00025: val_loss did not improve from 0.00019
# 13/13 [==============================] - 2s 134ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.2089e-04 - val_accuracy: 1.0000
# Epoch 26/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 00026: val_loss did not improve from 0.00019
# 13/13 [==============================] - 2s 136ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.9833e-04 - val_accuracy: 1.0000
# Epoch 27/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0557 - accuracy: 0.9667
# Epoch 00027: val_loss did not improve from 0.00019
# 13/13 [==============================] - 2s 134ms/step - loss: 0.0514 - accuracy: 0.9692 - val_loss: 2.9062e-04 - val_accuracy: 1.0000
# Epoch 28/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0120 - accuracy: 1.0000
# Epoch 00028: val_loss did not improve from 0.00019
# 13/13 [==============================] - 2s 133ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 2.9403e-04 - val_accuracy: 1.0000
# Epoch 29/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1546 - accuracy: 0.9500
# Epoch 00029: val_loss improved from 0.00019 to 0.00005, saving model to ./model.h5
# 13/13 [==============================] - 2s 152ms/step - loss: 0.1427 - accuracy: 0.9538 - val_loss: 5.2778e-05 - val_accuracy: 1.0000
# Epoch 30/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 00030: val_loss improved from 0.00005 to 0.00004, saving model to ./model.h5
# 13/13 [==============================] - 2s 151ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 3.6205e-05 - val_accuracy: 1.0000
# Epoch 31/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 00031: val_loss did not improve from 0.00004
# 13/13 [==============================] - 2s 132ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 8.0009e-05 - val_accuracy: 1.0000
# Epoch 32/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0224 - accuracy: 1.0000
# Epoch 00032: val_loss did not improve from 0.00004
# 13/13 [==============================] - 2s 135ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 6.9439e-05 - val_accuracy: 1.0000
# Epoch 33/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1197 - accuracy: 0.9500
# Epoch 00033: val_loss did not improve from 0.00004
# 13/13 [==============================] - 2s 134ms/step - loss: 0.2082 - accuracy: 0.9231 - val_loss: 6.8071e-04 - val_accuracy: 1.0000
# Epoch 34/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0209 - accuracy: 1.0000
# Epoch 00034: val_loss did not improve from 0.00004
# 13/13 [==============================] - 2s 143ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 3.4726e-04 - val_accuracy: 1.0000
# Epoch 35/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 00035: val_loss did not improve from 0.00004
# 13/13 [==============================] - 2s 134ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.1198e-04 - val_accuracy: 1.0000
# Epoch 36/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 00036: val_loss did not improve from 0.00004
# 13/13 [==============================] - 2s 135ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 5.3201e-05 - val_accuracy: 1.0000
# Epoch 37/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0867 - accuracy: 0.9667
# Epoch 00037: val_loss did not improve from 0.00004
# 13/13 [==============================] - 2s 134ms/step - loss: 0.0801 - accuracy: 0.9692 - val_loss: 4.8424e-05 - val_accuracy: 1.0000
# Epoch 38/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0788 - accuracy: 0.9667
# Epoch 00038: val_loss improved from 0.00004 to 0.00002, saving model to ./model.h5
# 13/13 [==============================] - 2s 153ms/step - loss: 0.0728 - accuracy: 0.9692 - val_loss: 1.9145e-05 - val_accuracy: 1.0000
# Epoch 39/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1397 - accuracy: 0.9500
# Epoch 00039: val_loss did not improve from 0.00002
# 13/13 [==============================] - 2s 134ms/step - loss: 0.1289 - accuracy: 0.9538 - val_loss: 5.2187e-05 - val_accuracy: 1.0000
# Epoch 40/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1022 - accuracy: 0.9667
# Epoch 00040: val_loss did not improve from 0.00002
# 13/13 [==============================] - 2s 136ms/step - loss: 0.0953 - accuracy: 0.9692 - val_loss: 3.8004e-04 - val_accuracy: 1.0000
# Epoch 41/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 00041: val_loss did not improve from 0.00002
# 13/13 [==============================] - 2s 136ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 7.6764e-04 - val_accuracy: 1.0000
# Epoch 42/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1382 - accuracy: 0.9333
# Epoch 00042: val_loss did not improve from 0.00002
# 13/13 [==============================] - 2s 135ms/step - loss: 0.1276 - accuracy: 0.9385 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 43/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 00043: val_loss did not improve from 0.00002
# 13/13 [==============================] - 2s 134ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 44/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0250 - accuracy: 1.0000
# Epoch 00044: val_loss did not improve from 0.00002
# 13/13 [==============================] - 2s 123ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 45/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1372 - accuracy: 0.9500
# Epoch 00045: val_loss did not improve from 0.00002
# 13/13 [==============================] - 2s 134ms/step - loss: 0.1270 - accuracy: 0.9538 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 46/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1055 - accuracy: 0.9833
# Epoch 00046: val_loss did not improve from 0.00002
# 13/13 [==============================] - 2s 136ms/step - loss: 0.0976 - accuracy: 0.9846 - val_loss: 0.0450 - val_accuracy: 1.0000
# Epoch 47/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0459 - accuracy: 0.9833
# Epoch 00047: val_loss did not improve from 0.00002
# 13/13 [==============================] - 2s 135ms/step - loss: 0.0631 - accuracy: 0.9692 - val_loss: 0.0221 - val_accuracy: 1.0000
# Epoch 48/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0155 - accuracy: 1.0000
# Epoch 00048: val_loss did not improve from 0.00002
# 13/13 [==============================] - 2s 134ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 00048: early stopping

# %%
import matplotlib.pyplot as plt

print(history.history.keys())

plt.figure()
plt.plot(history.history['accuracy'], 'orange', label='Training accuracy')
plt.plot(history.history['val_accuracy'], 'blue', label='Validation accuracy')
plt.plot(history.history['loss'], 'red', label='Training loss')
plt.plot(history.history['val_loss'], 'green', label='Validation loss')
plt.legend()
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ### Create the *Test* dataset

# %%
model = tf.keras.models.load_model('./model.h5')

# %%
test_dataset = p.get_dataset_by_name('TEST')
test_dataset.prepare()

# %%
import numpy as np
from PIL import Image
from tf_explain.core.grad_cam import GradCAM
from tf_explain.core.smoothgrad import SmoothGrad
import cv2
import matplotlib.pyplot as plt

img_width = 224
img_height = 224

plt.figure(figsize=(20, 10))

for i, image_id in enumerate(test_dataset.image_ids): 
    
    image = mdai.visualize.load_dicom_image(image_id, to_RGB=True)
    image = Image.fromarray(image)
    image = image.resize((img_width, img_height))
    
    X = np.empty((1, img_width, img_height, 3))
    X[0,:] = image
    y_prob = model.predict(X)
    y_classes = y_prob.argmax(axis=-1)
    
    pred_class = test_dataset.class_id_to_class_text(y_classes[0])
    pred_prob = y_prob[0][y_classes[0]]
    title = f'Pred: {pred_class}, Prob: {pred_prob:.3}'
    
    plt.subplot(len(test_dataset.image_ids), 3, i*3+1)
    plt.title(title)
    plt.imshow(image)
    plt.axis('off')
    
    explainer = GradCAM()
    output = explainer.explain(
        validation_data=(X, None),
        model=model,
        layer_name="conv_pw_13_relu",
        class_index=y_classes[0],
        colormap=cv2.COLORMAP_MAGMA,
    )
    
    plt.subplot(len(test_dataset.image_ids), 3, i*3+2)
    plt.imshow(output)
    plt.axis('off')
    
    explainer = SmoothGrad()
    output = explainer.explain(
        validation_data=(X, None),
        model=model,
        class_index=y_classes[0],
    )
    
    plt.subplot(len(test_dataset.image_ids), 3, i*3+3)
    plt.imshow(output, cmap='gray')
    plt.axis('off')
    
plt.show()
